# %% [markdown]
# # Business Problem Understanding
#
# **🎯 Business Problem Statement:
# "What are the major factors that affect student academic performance and how can we predict whether a student will pass or fail the final exam?"**

# %% [markdown]
# About Dataset
# Description
# This dataset provides a comprehensive overview of various factors affecting student performance in exams. It includes information on study habits, attendance, parental involvement, and other aspects influencing academic success.
#
# Column Descriptions
# Attribute	Description
# Hours_Studied	Number of hours spent studying per week.
# Attendance	Percentage of classes attended.
# Parental_Involvement	Level of parental involvement in the student's education (Low, Medium, High).
# Access_to_Resources	Availability of educational resources (Low, Medium, High).
# Extracurricular_Activities	Participation in extracurricular activities (Yes, No).
# Sleep_Hours	Average number of hours of sleep per night.
# Previous_Scores	Scores from previous exams.
# Motivation_Level	Student's level of motivation (Low, Medium, High).
# Internet_Access	Availability of internet access (Yes, No).
# Tutoring_Sessions	Number of tutoring sessions attended per month.
# Family_Income	Family income level (Low, Medium, High).
# Teacher_Quality	Quality of the teachers (Low, Medium, High).
# School_Type	Type of school attended (Public, Private).
# Peer_Influence	Influence of peers on academic performance (Positive, Neutral, Negative).
# Physical_Activity	Average number of hours of physical activity per week.
# Learning_Disabilities	Presence of learning disabilities (Yes, No).
# Parental_Education_Level	Highest education level of parents (High School, College, Postgraduate).
# Distance_from_Home	Distance from home to school (Near, Moderate, Far).
# Gender	Gender of the student (Male, Female).
# Exam_Score	Final exam score.

# %% [markdown]
# Student Performance Prediction Dataset 🎓📊
# Overview
# This dataset contains information about students' academic performance, study habits, and external factors affecting their final exam scores. It is designed for predictive modeling, data visualization, and educational analytics.
#
# Dataset Purpose
# This dataset is useful for:
#
# Predicting student final exam scores 📈
# Identifying key factors that impact academic performance 🎯
# Exploring feature importance in education-related datasets 📊
# Building machine learning models for regression and classification 🤖

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# Column Name | Description
# Student_ID | Unique identifier assigned to each student (alphanumeric).
# Gender | Biological sex of the student. Possible values: Male, Female.
# Study_Hours_per_Week | Number of hours the student spends studying on average per week (numeric).
# Attendance_Rate | Percentage of classes attended by the student (0 to 100%).
# Past_Exam_Scores | Average score from previous exams (out of 100).
# Parental_Education_Level | Highest education level of the student's parents. Values: High School, Bachelors, Masters, PhD.
# Internet_Access_at_Home | Whether the student has access to the internet at home. Values: Yes, No.
# Extracurricular_Activities | Whether the student participates in extracurricular activities. Values: Yes, No.
# Final_Exam_Score | Marks obtained by the student in the final exam (out of 100).
# Pass_Fail | Outcome of the final exam. Values: Pass, Fail.

# %%
df = pd.read_csv(r"C:\Users\L.RAMYA\OneDrive\Documents\student_performance_dataset.csv")

# %%
df.head()
# Out:
#   Student_ID  Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0       S147    Male                    31        68.267841                86
# 1       S136    Male                    16        78.222927                73
# 2       S209  Female                    21        87.525096                74
# 3       S458  Female                    27        92.076483                99
# 4       S078  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
# ...

# %%
df.shape
# Out:
# (708, 10)

# %% [markdown]
# **The dataset contains 708 individuals, each described by 10 attributes**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  708 non-null    object
#  1   Gender                      708 non-null    object
#  2   Study_Hours_per_Week        708 non-null    int64
#  3   Attendance_Rate             708 non-null    float64
#  4   Past_Exam_Scores            708 non-null    int64
#  5   Parental_Education_Level    708 non-null    object
#  6   Internet_Access_at_Home     708 non-null    object
#  7   Extracurricular_Activities  708 non-null    object
#  8   Final_Exam_Score            708 non-null    int64
#  9   Pass_Fail                   708 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 55.4+ KB

# %% [markdown]
# **The dataset contains information on student demographics, study habits, and performance, including gender, study hours, past exam scores, and final exam results. It helps analyze factors influencing students' success and failure in their final exams.**

# %%
df.dtypes
# Out:
# Student_ID                     object
# Gender                         object
# Study_Hours_per_Week            int64
# Attendance_Rate               float64
# Past_Exam_Scores                int64
# Parental_Education_Level       object
# Internet_Access_at_Home        object
# Extracurricular_Activities     object
# Final_Exam_Score                int64
# Pass_Fail                      object
# dtype: object

# %% [markdown]
# **Student_ID: object, Gender: object, Study_Hours_per_Week: int64, Attendance_Rate: float64, Past_Exam_Scores: int64, Parental_Education_Level: object, Internet_Access_at_Home: object
# Extracurricular_Activities: object, Final_Exam_Score: int64, Pass_Fail: object**

# %%
df.columns.to_list()
# Out:
# ['Student_ID',
#  'Gender',
#  'Study_Hours_per_Week',
#  'Attendance_Rate',
#  'Past_Exam_Scores',
#  'Parental_Education_Level',
#  'Internet_Access_at_Home',
#  'Extracurricular_Activities',
#  'Final_Exam_Score',
#  'Pass_Fail']

# %% [markdown]
# **These are columns names in agiven dataset**

# %%
df['Student_ID'].unique()
# Out:
# array(['S147', 'S136', 'S209', 'S458', 'S078', 'S417', 'S302', 'S009',
#        'S044', 'S331', 'S451', 'S059', 'S315', 'S295', 'S141', 'S274',
#        'S327', 'S413', 'S452', 'S386', 'S079', 'S375', 'S384', 'S207',
#        'S071', 'S489', 'S066', 'S018', 'S015', 'S155', 'S159', 'S368',
#        'S104', 'S329', 'S397', 'S097', 'S112', 'S370', 'S463', 'S060',
#        'S041', 'S216', 'S430', 'S377', 'S187', 'S233', 'S166', 'S419',
#        'S033', 'S185', 'S057', 'S372', 'S395', 'S211', 'S361', 'S382',
#        'S389', 'S387', 'S380', 'S020', 'S445', 'S099', 'S448', 'S408',
#        'S089', 'S049', 'S194', 'S121', 'S362', 'S322', 'S499', 'S251',
#        'S314', 'S200', 'S399', 'S072', 'S162', 'S440', 'S139', 'S449',
#        'S108', 'S476', 'S068', 'S178', 'S406', 'S340', 'S379', 'S246',
#        'S164', 'S008', 'S051', 'S142', 'S394', 'S045', 'S013', 'S085',
#        'S300', 'S438', 'S439', 'S012', 'S366', 'S180', 'S486', 'S431',
# ...

# %% [markdown]
# **The Student_ID column has 708 unique values, indicating that each student has a unique identifier in the dataset.**

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# **The Gender column contains two unique values: 'Male' and 'Female'.**

# %%
df['Study_Hours_per_Week'].unique()
# Out:
# array([31, 16, 21, 27, 37, 30, 24, 34, 35, 11, 25, 18, 12, 32, 39, 14, 36,
#        20, 26, 38, 15, 28, 29, 13, 23, 22, 19, 33, 10, 17], dtype=int64)

# %% [markdown]
# **The Study_Hours_per_Week column contains 29 unique values, which are integers ranging from 10 to 39 hours. This indicates a variation in the number of hours students dedicate to studying each week.**

# %%
df['Attendance_Rate'].unique()
# Out:
# array([68.26784098, 78.22292713, 87.52509624, 92.07648302, 98.65551746,
#        84.15919282, 89.38949444, 50.68359824, 80.8631856 , 65.49684631,
#        69.83246865, 92.10457075, 78.8815977 , 66.60732063, 62.21765777,
#        55.03973015, 93.03160089, 71.08519673, 97.70434683, 85.19730676,
#        80.09676978, 97.22048628, 93.82220379, 89.07572409, 70.01502445,
#        99.02884001, 78.98249672, 68.89252746, 79.25747662, 50.91212407,
#        78.79992089, 77.83607924, 96.20208796, 59.22314357, 93.053401  ,
#        68.86429826, 84.35827527, 90.26574837, 73.71186544, 88.44588707,
#        81.96806785, 65.80982911, 86.60922892, 70.31961541, 60.08652312,
#        66.6407893 , 85.92286354, 76.48308393, 90.81928676, 77.4301559 ,
#        89.82358878, 80.15987011, 88.69172616, 91.25663383, 62.6944282 ,
#        92.40640477, 66.79329286, 95.53120018, 81.66203875, 60.25226643,
#        91.85394954, 93.41505535, 86.07664306, 87.08434721, 56.43741991,
# ...

# %% [markdown]
# **The Attendance_Rate column contains unique values that are likely in decimal or percentage format, representing the proportion of classes attended by each student.**

# %%
df['Past_Exam_Scores'].unique()
# Out:
# array([ 86,  73,  74,  99,  63,  77,  95,  78,  94,  58,  81,  64,  62,
#         71,  55,  79,  93,  57,  92,  69,  85,  96,  66,  67,  52,  91,
#         83,  82,  88,  84,  80,  56,  51,  70,  97,  60,  76,  68,  65,
#         54,  89,  87,  72,  75, 100,  53,  61,  50,  98,  90,  59],
#       dtype=int64)

# %% [markdown]
# **The unique values in the Past_Exam_Scores column would represent the different scores students have achieved in past exams.**

# %%
df['Parental_Education_Level'].unique()
# Out:
# array(['High School', 'PhD', 'Bachelors', 'Masters'], dtype=object)

# %% [markdown]
# **The Parental_Education_Level column has six unique categories: High School, Bachelor, Master, PhD, Associate, and None. It reflects the highest level of education attained by the students' parents, which may impact the students' academic performance.**

# %%
df[ 'Internet_Access_at_Home'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# **The `Internet_Access_at_Home` column has two unique values: "Yes" and "No," indicating whether the students have internet access at home, which could affect their study habits and academic performance.**

# %%
df['Extracurricular_Activities'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# **The `Extracurricular_Activities` column has two unique values: "Yes" and "No," indicating whether the students participate in extracurricular activities.**

# %%
df['Final_Exam_Score'].unique()
# Out:
# array([63, 50, 55, 65, 70, 61, 57, 62, 59, 77, 56, 58, 64, 71, 67, 54, 68,
#        53, 66, 51, 60, 52, 74, 72, 69, 76, 73], dtype=int64)

# %% [markdown]
# **The `Final_Exam_Score` column contains numeric values representing students' final exam scores. Since it’s a continuous variable, it has many unique values ranging across a possible score scale (e.g., 0 to 100).**

# %%
df['Pass_Fail'].unique()
# Out:
# array(['Pass', 'Fail'], dtype=object)

# %% [markdown]
# **The `Pass_Fail` column has two unique values: `'Pass'` and `'Fail'`, indicating whether each student passed or failed the final exam.**

# %%
df['Pass_Fail'].value_counts()
# Out:
# Pass_Fail
# Pass    354
# Fail    354
# Name: count, dtype: int64

# %% [markdown]
# **The dataset has an equal distribution of pass and fail outcomes:
# **354 students passed** and **354 students failed**, showing a perfectly balanced target variable.**

# %%
df['Extracurricular_Activities'].value_counts()
# Out:
# Extracurricular_Activities
# No     361
# Yes    347
# Name: count, dtype: int64

# %% [markdown]
# **Most students **(361)** are not involved in extracurricular activities, while **347** students participate in them. The distribution is fairly balanced, but slightly more students chose **'No'**.**

# %%
df[ 'Internet_Access_at_Home'].value_counts()
# Out:
# Internet_Access_at_Home
# No     381
# Yes    327
# Name: count, dtype: int64

# %% [markdown]
# **A majority of students **(381)** do not have internet access at home, while **327** students do.
# This could influence study habits and performance, especially for online resources.**

# %%
df['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# Bachelors      189
# High School    183
# Masters        171
# PhD            165
# Name: count, dtype: int64

# %% [markdown]
# **Most parents have a **Bachelor’s degree (189)**, followed closely by **High School (183)**, **Masters (171)**, and **PhD (165)**.
# This shows a fairly even distribution across different education levels**.

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    375
# Male      333
# Name: count, dtype: int64

# %% [markdown]
# **There are **more female students (375)** than male students (333) in the dataset.
# The gender distribution is slightly skewed towards females.**

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
continous = ['Study_Hours_per_Week','Attendance_Rate','Past_Exam_Scores','Final_Exam_Score']
categorical =['Student_ID']
count=['Gender','Parental_Education_Level','Internet_Access_at_Home','Pass_Fail','Extracurricular_Activities']

# %%
df[continous].describe()
# Out:
#        Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# count            708.000000       708.000000        708.000000
# mean              26.132768        78.107722         77.871469
# std                8.877727        13.802802         14.402739
# min               10.000000        50.116970         50.000000
# 25%               19.000000        67.550094         65.000000
# 50%               27.000000        79.363046         79.000000
# 75%               34.000000        89.504232         91.000000
# max               39.000000        99.967675        100.000000
#
#        Final_Exam_Score
# count        708.000000
# mean          58.771186
# std            6.705877
# min           50.000000
# 25%           52.000000
# 50%           59.500000
# 75%           64.000000
# max           77.000000

# %% [markdown]
# ** On average, students study **~26 hours/week**, have **~78% attendance**, and scored **~59** in the final exam.
# - The **final exam score** ranges from **50 to 77**, with **most students scoring around 59.5 (median)**.

# %%
df[categorical].describe()
# Out:
#        Student_ID
# count         708
# unique        500
# top          S339
# freq            6

# %%
import matplotlib.pyplot as plt

# List of continuous columns
continuous = ['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']

# Plot histograms
plt.figure(figsize=(12, 8))

for i, col in enumerate(continuous):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of continuous columns
continuous = ['Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Final_Exam_Score']

# Set up the plot
plt.figure(figsize=(12, 8))

# Create boxplots for each continuous variable
for i, col in enumerate(continuous):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(y=df[col], color='lightgreen')
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of categorical columns
count = ['Gender', 'Parental_Education_Level', 'Internet_Access_at_Home', 'Pass_Fail', 'Extracurricular_Activities']

# Plot count plots
plt.figure(figsize=(15, 12))

for i, col in enumerate(count):
    plt.subplot(3, 2, i + 1)
    sns.countplot(data=df, x=col, palette='Set2')
    plt.title(f'Count Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
df[continous].skew()
# Out:
# Study_Hours_per_Week   -0.239870
# Attendance_Rate        -0.329960
# Past_Exam_Scores       -0.192021
# Final_Exam_Score        0.157897
# dtype: float64

# %%
df[continous].corr()
# Out:
#                       Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# Study_Hours_per_Week              1.000000        -0.008150         -0.014756
# Attendance_Rate                  -0.008150         1.000000          0.000412
# Past_Exam_Scores                 -0.014756         0.000412          1.000000
# Final_Exam_Score                  0.370387         0.460478          0.489516
#
#                       Final_Exam_Score
# Study_Hours_per_Week          0.370387
# Attendance_Rate               0.460478
# Past_Exam_Scores              0.489516
# Final_Exam_Score              1.000000

# %%
sns.heatmap(df[continous].corr(),annot=True)
plt.show()

# %% [markdown]
# # Data cleaning

# %%
df.duplicated().sum()
# Out:
# 208

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Student_ID                    0
# Gender                        0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Past_Exam_Scores              0
# Parental_Education_Level      0
# Internet_Access_at_Home       0
# Extracurricular_Activities    0
# Final_Exam_Score              0
# Pass_Fail                     0
# dtype: int64

# %%
df = df.drop(columns=['Student_ID'])

# %%
df
# Out:
#      Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0      Male                    31        68.267841                86
# 1      Male                    16        78.222927                73
# 2    Female                    21        87.525096                74
# 3    Female                    27        92.076483                99
# 4    Female                    37        98.655517                63
# ..      ...                   ...              ...               ...
# 701  Female                    21        69.858192                90
# 702  Female                    22        93.349688                76
# 703    Male                    14        84.658761                78
# 705    Male                    25        98.384969                75
# 707  Female                    22        80.404392                93
#
#     Parental_Education_Level Internet_Access_at_Home  \
# 0                High School                     Yes
# ...

# %% [markdown]
# # ANALAYSIS

# %%
gender_counts=df.groupby('Gender')['Pass_Fail'].count()
gender_counts
# Out:
# Gender
# Female    256
# Male      244
# Name: Pass_Fail, dtype: int64

# %%
# Plotting
gender_counts.plot(kind='bar', color=['skyblue', 'pink'])

plt.title('Total Students by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define intervals for study hours (you can adjust the bins as needed)
bins = [0, 10, 20, 30, 40, 50]
labels = ['0-10', '11-20', '21-30', '31-40', '41-50']

# Create a new binned column
df['Study_Hours_Bin'] = pd.cut(df['Study_Hours_per_Week'], bins=bins, labels=labels)

# Group by interval and Pass/Fail
grouped = df.groupby(['Study_Hours_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Plot
grouped.plot(kind='bar', figsize=(10, 6), color=['gray', 'black'])

plt.title('Pass/Fail Count by Study Hours Interval')
plt.xlabel('Study Hours per Week (Interval)')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define intervals for Attendance Rate
bins = [0, 60, 70, 80, 90, 100]
labels = ['0-60%', '61-70%', '71-80%', '81-90%', '91-100%']

# Create a new binned column
df['Attendance_Bin'] = pd.cut(df['Attendance_Rate'], bins=bins, labels=labels)

# Group by interval and Pass/Fail
attendance_grouped = df.groupby(['Attendance_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Plot
attendance_grouped.plot(kind='bar', figsize=(10, 6), color=['purple', 'pink'])

plt.title('Pass/Fail Count by Attendance Rate Interval')
plt.xlabel('Attendance Rate (%)')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define intervals for Past Exam Scores
bins = [0, 50, 60, 70, 80, 90, 100]
labels = ['0-50', '51-60', '61-70', '71-80', '81-90', '91-100']

# Create a binned column
df['Past_Score_Bin'] = pd.cut(df['Past_Exam_Scores'], bins=bins, labels=labels)

# Group by interval and Pass/Fail
past_scores_grouped = df.groupby(['Past_Score_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Plot
past_scores_grouped.plot(kind='bar', figsize=(10, 6), color=['gold', 'mediumseagreen'])

plt.title('Pass/Fail Count by Past Exam Score Interval')
plt.xlabel('Past Exam Score (%)')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grouping
edu_grouped = df.groupby(['Parental_Education_Level', 'Pass_Fail']).size().unstack(fill_value=0)

# Plotting
edu_grouped.plot(kind='bar', figsize=(10, 6), color=['lightblue', '#C71585'])

plt.title('Pass/Fail Count by Parental Education Level')
plt.xlabel('Parental Education Level')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grouping by 'Internet_Access_at_Home' and 'Pass_Fail'
internet_grouped = df.groupby(['Internet_Access_at_Home', 'Pass_Fail']).size().unstack(fill_value=0)

# Plotting with a color palette (dark pink and green)
internet_grouped.plot(kind='bar', figsize=(10, 6), color=['#C71585', 'darkgreen'])

plt.title('Pass/Fail Count by Internet Access at Home')
plt.xlabel('Internet Access at Home')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grouping by 'Extracurricular_Activities' and 'Pass_Fail'
extracurricular_grouped = df.groupby(['Extracurricular_Activities', 'Pass_Fail']).size().unstack(fill_value=0)

# Plotting with a color palette (dark pink and green)
extracurricular_grouped.plot(kind='bar', figsize=(10, 6), color=['lightblue', 'green'])

plt.title('Pass/Fail Count by Extracurricular Activities')
plt.xlabel('Extracurricular Activities')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define intervals for Final Exam Scores
bins = [0, 50, 60, 70, 80, 90, 100]
labels = ['0-50', '51-60', '61-70', '71-80', '81-90', '91-100']

# Create a new binned column
df['Final_Score_Bin'] = pd.cut(df['Final_Exam_Score'], bins=bins, labels=labels)

# Grouping by Final Exam Score intervals and Pass/Fail
final_score_grouped = df.groupby(['Final_Score_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Plotting with a color palette (dark pink and green)
final_score_grouped.plot(kind='bar', figsize=(10, 6), color=['#C71585', 'lightgreen'])

plt.title('Pass/Fail Count by Final Exam Score Interval')
plt.xlabel('Final Exam Score (%)')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
df
# Out:
#      Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0      Male                    31        68.267841                86
# 1      Male                    16        78.222927                73
# 2    Female                    21        87.525096                74
# 3    Female                    27        92.076483                99
# 4    Female                    37        98.655517                63
# ..      ...                   ...              ...               ...
# 701  Female                    21        69.858192                90
# 702  Female                    22        93.349688                76
# 703    Male                    14        84.658761                78
# 705    Male                    25        98.384969                75
# 707  Female                    22        80.404392                93
#
#     Parental_Education_Level Internet_Access_at_Home  \
# 0                High School                     Yes
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grouping by 'Gender', 'Study_Hours_Bin' and 'Pass_Fail'
grouped = df.groupby(['Gender', 'Study_Hours_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Plotting
grouped.plot(kind='bar', figsize=(12, 6), color=['lightblue', 'pink'])

plt.title('Pass/Fail Count by Gender and Study Hours per Week')
plt.xlabel('Gender and Study Hours Interval')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0    Male                    31        68.267841                86
# 1    Male                    16        78.222927                73
# 2  Female                    21        87.525096                74
# 3  Female                    27        92.076483                99
# 4  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail Study_Hours_Bin Attendance_Bin Past_Score_Bin  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Gender, Attendance_Bin, and Pass_Fail
grouped = df.groupby(['Gender', 'Attendance_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Flatten the index for plotting
grouped.index = grouped.index.map(lambda x: f'{x[0]} - {x[1]}')

# Plot
grouped.plot(kind='bar', figsize=(14, 6), color=['#008080', '#FFD700'])

plt.title('Pass/Fail Count by Gender and Attendance Rate Bin')
plt.xlabel('Gender and Attendance Bin')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Grouping by Gender, Past_Score_Bin, and Pass_Fail
grouped = df.groupby(['Gender', 'Past_Score_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Combine Gender and Score Bin for X-axis labels
grouped.index = grouped.index.map(lambda x: f'{x[0]} - {x[1]}')

# Plot
grouped.plot(kind='bar', figsize=(14, 6), color=['#8B0000', '#FFA500'])

# Customizations
plt.title('Pass/Fail Count by Gender and Past Exam Score Bin')
plt.xlabel('Gender and Past Score Bin')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Gender, Parental Education Level, and Pass_Fail
grouped = df.groupby(['Gender', 'Parental_Education_Level', 'Pass_Fail']).size().unstack(fill_value=0)

# Flatten the index for better readability in the plot
grouped.index = grouped.index.map(lambda x: f'{x[0]} - {x[1]}')

# Plot the grouped bar chart
grouped.plot(kind='bar', figsize=(14, 6), color=['#C71585', '#4169E1'])

# Customizations
plt.title('Pass/Fail Count by Gender and Parental Education Level')
plt.xlabel('Gender and Parental Education Level')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Gender, Internet_Access_at_Home, and Pass_Fail
grouped = df.groupby(['Gender', 'Internet_Access_at_Home', 'Pass_Fail']).size().unstack(fill_value=0)

# Flatten the index for better readability in the plot
grouped.index = grouped.index.map(lambda x: f'{x[0]} - {x[1]}')

# Plot the grouped bar chart
grouped.plot(kind='bar', figsize=(14, 6), color=['#FFA500', '#C71585'])

# Customizations
plt.title('Pass/Fail Count by Gender and Internet Access at Home')
plt.xlabel('Gender and Internet Access at Home')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0    Male                    31        68.267841                86
# 1    Male                    16        78.222927                73
# 2  Female                    21        87.525096                74
# 3  Female                    27        92.076483                99
# 4  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail Study_Hours_Bin Attendance_Bin Past_Score_Bin  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Gender, Extracurricular_Activities, and Pass_Fail
grouped = df.groupby(['Gender', 'Extracurricular_Activities', 'Pass_Fail']).size().unstack(fill_value=0)

# Flatten the index for better readability in the plot
grouped.index = grouped.index.map(lambda x: f'{x[0]} - {x[1]}')

# Plot the grouped bar chart
grouped.plot(kind='bar', figsize=(14, 6), color=['#FFD700', '#008080'])

# Customizations
plt.title('Pass/Fail Count by Gender and Extracurricular Activities')
plt.xlabel('Gender and Extracurricular Activities')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Gender, Final_Score_Bin, and Pass_Fail
grouped = df.groupby(['Gender', 'Final_Score_Bin', 'Pass_Fail']).size().unstack(fill_value=0)

# Flatten the index for better readability in the plot
grouped.index = grouped.index.map(lambda x: f'{x[0]} - {x[1]}')

# Plot the grouped bar chart
grouped.plot(kind='bar', figsize=(14, 6), color=['#90EE90', '#A9A9A9'])

# Customizations
plt.title('Pass/Fail Count by Gender and Final Score Bin')
plt.xlabel('Gender and Final Score Bin')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.legend(title='Pass/Fail')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0    Male                    31        68.267841                86
# 1    Male                    16        78.222927                73
# 2  Female                    21        87.525096                74
# 3  Female                    27        92.076483                99
# 4  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail Study_Hours_Bin Attendance_Bin Past_Score_Bin  \
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by Study_Hours_Bin, Attendance_Bin, and Pass_Fail and get counts
grouped = df.groupby(['Study_Hours_Bin', 'Attendance_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Study_Hours_Bin', y='Count', hue='Pass_Fail', data=grouped)

# Customizations
plt.title('Pass/Fail Count by Study Hours Bin and Attendance Bin')
plt.xlabel('Study Hours Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by Study_Hours_Bin, Past_Score_Bin, and Pass_Fail and get counts
grouped = df.groupby(['Study_Hours_Bin', 'Past_Score_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Study_Hours_Bin', y='Count', hue='Pass_Fail', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Study Hours Bin and Past Score Bin')
plt.xlabel('Study Hours Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by Study_Hours_Bin, Parental_Education_Level, and Pass_Fail and get counts
grouped = df.groupby(['Study_Hours_Bin', 'Parental_Education_Level', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Study_Hours_Bin', y='Count', hue='Parental_Education_Level', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Study Hours Bin and Parental Education Level')
plt.xlabel('Study Hours Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0    Male                    31        68.267841                86
# 1    Male                    16        78.222927                73
# 2  Female                    21        87.525096                74
# 3  Female                    27        92.076483                99
# 4  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail Study_Hours_Bin Attendance_Bin Past_Score_Bin  \
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by Study_Hours_Bin, Internet_Access_at_Home, and Pass_Fail and get counts
grouped = df.groupby(['Study_Hours_Bin', 'Internet_Access_at_Home', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Study_Hours_Bin', y='Count', hue='Internet_Access_at_Home', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Study Hours Bin and Internet Access at Home')
plt.xlabel('Study Hours Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Study_Hours_Bin', 'Final_Score_Bin', and 'Pass_Fail' and get counts
grouped = df.groupby(['Study_Hours_Bin', 'Final_Score_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Study_Hours_Bin', y='Count', hue='Final_Score_Bin', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Study Hours Bin and Final Exam Score Bin')
plt.xlabel('Study Hours Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0    Male                    31        68.267841                86
# 1    Male                    16        78.222927                73
# 2  Female                    21        87.525096                74
# 3  Female                    27        92.076483                99
# 4  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail Study_Hours_Bin Attendance_Bin Past_Score_Bin  \
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Attendance_Bin', 'Past_Score_Bin', and 'Pass_Fail' and get counts
grouped = df.groupby(['Attendance_Bin', 'Past_Score_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Attendance_Bin', y='Count', hue='Past_Score_Bin', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Attendance Bin and Past Exam Score Bin')
plt.xlabel('Attendance Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data
grouped = df.groupby(['Study_Hours_Bin', 'Attendance_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Define custom colors for Pass and Fail
custom_palette = {
    'Pass': '#90EE90',    # Light green
    'Fail': '#C71585'     # Dark pink
}

# Plot
plt.figure(figsize=(14, 7))
sns.barplot(
    x='Study_Hours_Bin',
    y='Count',
    hue='Pass_Fail',
    data=grouped,
    palette=custom_palette,
    ci=None
)

# Customizations
plt.title('Pass/Fail Count by Study Hours Bin and Attendance Bin')
plt.xlabel('Study Hours Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Attendance_Bin', 'Internet_Access_at_Home', and 'Pass_Fail' and get counts
grouped = df.groupby(['Attendance_Bin', 'Internet_Access_at_Home', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Attendance_Bin', y='Count', hue='Internet_Access_at_Home', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Attendance Bin and Internet Access at Home')
plt.xlabel('Attendance Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Attendance_Bin', 'Final_Score_Bin', and 'Pass_Fail' and get counts
grouped = df.groupby(['Attendance_Bin', 'Final_Score_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Attendance_Bin', y='Count', hue='Final_Score_Bin', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Attendance Bin and Final Score Bin')
plt.xlabel('Attendance Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Past_Score_Bin', 'Parental_Education_Level', and 'Pass_Fail' and get counts
grouped = df.groupby(['Past_Score_Bin', 'Parental_Education_Level', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Past_Score_Bin', y='Count', hue='Parental_Education_Level', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Past Score Bin and Parental Education Level')
plt.xlabel('Past Score Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Past_Score_Bin', 'Internet_Access_at_Home', and 'Pass_Fail' and get counts
grouped = df.groupby(['Past_Score_Bin', 'Internet_Access_at_Home', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Past_Score_Bin', y='Count', hue='Internet_Access_at_Home', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Past Score Bin and Internet Access at Home')
plt.xlabel('Past Score Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Gender  Study_Hours_per_Week  Attendance_Rate  Past_Exam_Scores  \
# 0    Male                    31        68.267841                86
# 1    Male                    16        78.222927                73
# 2  Female                    21        87.525096                74
# 3  Female                    27        92.076483                99
# 4  Female                    37        98.655517                63
#
#   Parental_Education_Level Internet_Access_at_Home Extracurricular_Activities  \
# 0              High School                     Yes                        Yes
# 1                      PhD                      No                         No
# 2                      PhD                     Yes                         No
# 3                Bachelors                      No                         No
# 4                  Masters                      No                        Yes
#
#    Final_Exam_Score Pass_Fail Study_Hours_Bin Attendance_Bin Past_Score_Bin  \
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Past_Score_Bin', 'Extracurricular_Activities', and 'Pass_Fail' and get counts
grouped = df.groupby(['Past_Score_Bin', 'Extracurricular_Activities', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Past_Score_Bin', y='Count', hue='Extracurricular_Activities', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Past Score Bin and Extracurricular Activities')
plt.xlabel('Past Score Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'Past_Score_Bin', 'Final_Exam_Bin', and 'Pass_Fail' and get counts
grouped = df.groupby(['Past_Score_Bin', 'Final_Score_Bin', 'Pass_Fail']).size().reset_index(name='Count')

# Plot the grouped bar plot
plt.figure(figsize=(14, 7))
sns.barplot(x='Past_Score_Bin', y='Count', hue='Final_Score_Bin', data=grouped, ci=None)

# Customizations
plt.title('Pass/Fail Count by Past Score Bin and Final Exam Bin')
plt.xlabel('Past Score Bin')
plt.ylabel('Count of Pass/Fail')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
